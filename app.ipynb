# %%
from typing import TypedDict, Annotated, Optional
from langgraph.graph import add_messages, StateGraph, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.memory import MemorySaver
from uuid import uuid4
import json

load_dotenv()

llm = ChatOpenAI(model="gpt-4o")

# %%
search_tool = TavilySearchResults(max_results=4)

tools = [search_tool]

memory = MemorySaver()

# %%
llm_with_tools = llm.bind_tools(tools=tools)

# %%
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage

class State(TypedDict):
    messages: Annotated[list, add_messages]

async def model(state: State):
    result = await llm_with_tools.ainvoke(state["messages"])
    return {
        "messages": [result], 
    }

async def tools_router(state: State):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    
async def tool_node(state):
    """Custom tool node that handles tool calls from the LLM."""
    # Get the tool calls from the last message
    tool_calls = state["messages"][-1].tool_calls
    
    # Initialize list to store tool messages
    tool_messages = []
    
    # Process each tool call
    for tool_call in tool_calls:
        tool_name = tool_call["name"]
        tool_args = tool_call["args"]
        tool_id = tool_call["id"]
        
        # Handle the search tool
        if tool_name == "tavily_search_results_json":
            # Execute the search tool with the provided arguments
            search_results = await search_tool.ainvoke(tool_args)
            
            # Create a ToolMessage for this result
            tool_message = ToolMessage(
                content=str(search_results),
                tool_call_id=tool_id,
                name=tool_name
            )
            
            tool_messages.append(tool_message)
    
    # Add the tool messages to the state
    return {"messages": tool_messages}

graph_builder = StateGraph(State)

graph_builder.add_node("model", model)
graph_builder.add_node("tool_node", tool_node)
graph_builder.set_entry_point("model")

graph_builder.add_conditional_edges("model", tools_router)
graph_builder.add_edge("tool_node", "model")

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
config = {
    "configurable": {
        "thread_id": 5
    }
}

response = await graph.ainvoke({
    "messages": [HumanMessage(content="When is the next spaceX launch?")], 
}, config=config)

response
# Out:
# {'messages': [HumanMessage(content='When is the next spaceX launch?', additional_kwargs={}, response_metadata={}, id='043f673e-b60f-4c86-80aa-6f0578fb856d'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_g5ZuPI1hM7g2DDwECxZtykzU', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c8271a3c-cc8e-4e98-9e4d-8b0fc20c0d02-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_g5ZuPI1hM7g2DDwECxZtykzU', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\n[Details](https://nextspaceflight.com/launches/details/7874)[Watch](https://www.spacex.com/launches/mission/?missionId=sl-12-26)\\n\\n CASC \\n\\n##### Long March 2D | Unknown Payload\\n\\nSat Jun 14, 2025 07:55 UTC\\n\\nSite 9401 (SLS-2), Jiuquan Satellite Launch Center, China \\n\\n[Details](https://nextspaceflight.com/launches/details/7873)\\n\\n ULA\'}]', name='tavily_search_results_json', id='78d0580c-03ad-4dfb-b322-33fc05709247', tool_call_id='call_g5ZuPI1hM7g2DDwECxZtykzU'),
#   AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024. This launch will be for the Starlink-197 (8-19) mission using a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 1156, 'total_tokens': 1196, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-758ae3a9-72b7-45da-8a88-b9d9f49f6761-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 40, 'total_tokens': 1196, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
config = {
    "configurable": {
        "thread_id": 8
    }
}

# Use async for to iterate over the async generator
async for event in graph.astream_events({
    "messages": [HumanMessage(content="When is the next spacex launch?")],
}, config=config, version="v2"):
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': 'LangGraph', 'tags': [], 'run_id': 'f07acb31-b2ef-4e12-9087-24e54b9df997', 'metadata': {'thread_id': 8}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'run_id': '991dbd54-bf80-430c-ae94-3e197cc0f96a', 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': '_write', 'tags': ['seq:step:1', 'langsmith:hidden', 'langsmith:hidden'], 'run_id': 'd1f7f169-7e4f-492c-b9cc-6f11084c863a', 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '991dbd54-bf80-430c-ae94-3e197cc0f96a']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'run_id': 'd1f7f169-7e4f-492c-b9cc-6f11084c863a', 'name': '_write', 'tags': ['seq:step:1', 'langsmith:hidden', 'langsmith:hidden'], 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '991dbd54-bf80-430c-ae94-3e197cc0f96a']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': '_write', 'tags': ['seq:step:3', 'langsmith:hidden', 'langsmith:hidden'], 'run_id': 'e2d425eb-d777-4ae8-a06a-3c8af0aa8766', 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '991dbd54-bf80-430c-ae94-3e197cc0f96a']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'run_id': 'e2d425eb-d777-4ae8-a06a-3c8af0aa8766', 'name': '_write', 'tags': ['seq:step:3', 'langsmith:hidden', 'langsmith:hidden'], 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '991dbd54-bf80-430c-ae94-3e197cc0f96a']}
# {'event': 'on_chain_stream', 'run_id': '991dbd54-bf80-430c-ae94-3e197cc0f96a', 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'data': {'chunk': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'run_id': '991dbd54-bf80-430c-ae94-3e197cc0f96a', 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'thread_id': 8, 'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:4b81e216-aeef-7788-8b89-574c4ed3d664'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': '6bbab859-1496-4874-b957-14bb15cc7ba7', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'run_id': 'db85ed06-7e10-435d-aa4b-51af7e557ccd', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '6bbab859-1496-4874-b957-14bb15cc7ba7']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, 'input': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'run_id': 'db85ed06-7e10-435d-aa4b-51af7e557ccd', 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '6bbab859-1496-4874-b957-14bb15cc7ba7']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'name': 'tools_router', 'tags': ['seq:step:4'], 'run_id': '0b7b89ef-e029-4cbe-9062-4fe1e57de686', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '6bbab859-1496-4874-b957-14bb15cc7ba7']}
# {'event': 'on_chain_end', 'data': {'output': 'tool_node', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'run_id': '0b7b89ef-e029-4cbe-9062-4fe1e57de686', 'name': 'tools_router', 'tags': ['seq:step:4'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '6bbab859-1496-4874-b957-14bb15cc7ba7']}
# {'event': 'on_chain_stream', 'run_id': '6bbab859-1496-4874-b957-14bb15cc7ba7', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'data': {'chunk': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7')]}}, 'run_id': '6bbab859-1496-4874-b957-14bb15cc7ba7', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ['start:model'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b375b150-31bc-e8f8-88a2-51dec01e851d'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_stream', 'run_id': 'f07acb31-b2ef-4e12-9087-24e54b9df997', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'name': 'tool_node', 'tags': ['graph:step:2'], 'run_id': 'c2a7258c-fc0d-450b-ab84-0dbe268e2916', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ['branch:model:tools_router:tool_node'], 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:16e1e67f-6159-50c2-77a0-f4368aea99e4'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\n[Details](https://nextspaceflight.com/launches/details/7874)[Watch](https://www.spacex.com/launches/mission/?missionId=sl-12-26)\\n\\n CASC \\n\\n##### Long March 2D | Unknown Payload\\n\\nSat Jun 14, 2025 07:55 UTC\\n\\nSite 9401 (SLS-2), Jiuquan Satellite Launch Center, China \\n\\n[Details](https://nextspaceflight.com/launches/details/7873)\\n\\n ULA\'}]', name='tavily_search_results_json', tool_call_id='call_z73NJc4oUnbULbQS5btOSvje')]}}, 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'run_id': '5d78258b-64f4-405a-81ee-ca6434bccdff', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ['branch:model:tools_router:tool_node'], 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:16e1e67f-6159-50c2-77a0-f4368aea99e4'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', 'c2a7258c-fc0d-450b-ab84-0dbe268e2916']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\n[Details](https://nextspaceflight.com/launches/details/7874)[Watch](https://www.spacex.com/launches/mission/?missionId=sl-12-26)\\n\\n CASC \\n\\n##### Long March 2D | Unknown Payload\\n\\nSat Jun 14, 2025 07:55 UTC\\n\\nSite 9401 (SLS-2), Jiuquan Satellite Launch Center, China \\n\\n[Details](https://nextspaceflight.com/launches/details/7873)\\n\\n ULA\'}]', name='tavily_search_results_json', tool_call_id='call_z73NJc4oUnbULbQS5btOSvje')]}, 'input': {'messages': [ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- | ...
# {'event': 'on_chain_stream', 'run_id': 'c2a7258c-fc0d-450b-ab84-0dbe268e2916', 'name': 'tool_node', 'tags': ['graph:step:2'], 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ['branch:model:tools_router:tool_node'], 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:16e1e67f-6159-50c2-77a0-f4368aea99e4'}, 'data': {'chunk': {'messages': [ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\n[Details](https://nextspaceflight.com/launches/details/7874)[Watch](https://www.spacex.com/launches/mission/?missionId=sl-12-26)\\n\\n CASC \\n\\n##### Long March 2D | Unknown Payload\\n\\nSat Jun 14, 2025 07:55 UTC\\n\\nSite 9401 (SLS-2), Jiuquan Satellite Launch Center, China \\n\\n[Details](https://nextspaceflight.com/launches/details/7873)\\n\\n ULA\'}]', name='tavily_search_results_json', tool_call_id='call_z73NJc4oUnbULbQS5btOSvje')]}}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\n[Details](https://nextspaceflight.com/launches/details/7874)[Watch](https://www.spacex.com/launches/mission/?missionId=sl-12-26)\\n\\n CASC \\n\\n##### Long March 2D | Unknown Payload\\n\\nSat Jun 14, 2025 07:55 UTC\\n\\nSite 9401 (SLS-2), Jiuquan Satellite Launch Center, China \\n\\n[Details](https://nextspaceflight.com/launches/details/7873)\\n\\n ULA\'}]', name='tavily_search_results_json', tool_call_id='call_z73NJc4oUnbULbQS5btOSvje')]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fin ...
# {'event': 'on_chain_stream', 'run_id': 'f07acb31-b2ef-4e12-9087-24e54b9df997', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'tool_node': {'messages': [ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\n[Details](https://nextspaceflight.com/launches/details/7874)[Watch](https://www.spacex.com/launches/mission/?missionId=sl-12-26)\\n\\n CASC \\n\\n##### Long March 2D | Unknown Payload\\n\\nSat Jun 14, 2025 07:55 UTC\\n\\nSite 9401 (SLS-2), Jiuquan Satellite Launch Center, China \\n\\n[Details](https://nextspaceflight.com/launches/details/7873)\\n\\n ULA\'}]', name='tavily_search_results_json', id='d47ced38-f508-4e7c-acfb-310533ba7a50', tool_call_id='call_z73NJc4oUnbULbQS5btOSvje')]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA  ...
# {'event': 'on_chain_start', 'data': {'input': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024, featuring the Starlink-197 mission on a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1156, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e1a08ab-b0f8-423b-81a0-a1535b37318e-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 31, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'run_id': 'f424da3e-b30a-49a8-9aec-1ac15ab405b6', 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ['tool_node'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:4337c54f-c9a7-fa52-6222-e5188d35bed9'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '556b7f76-c291-4bdb-b2aa-cdbe0ae427d0']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024, featuring the Starlink-197 mission on a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1156, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e1a08ab-b0f8-423b-81a0-a1535b37318e-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 31, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, 'input': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024, featuring the Starlink-197 mission on a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1156, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e1a08ab-b0f8-423b-81a0-a1535b37318e-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 31, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'run_id': 'f424da3e-b30a-49a8-9aec-1ac15ab405b6', 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ['tool_node'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:4337c54f-c9a7-fa52-6222-e5188d35bed9'}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997', '556b7f76-c291-4bdb-b2aa-cdbe0ae427d0']}
# ...
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral ...
# {'event': 'on_chain_stream', 'run_id': '556b7f76-c291-4bdb-b2aa-cdbe0ae427d0', 'name': 'model', 'tags': ['graph:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ['tool_node'], 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:4337c54f-c9a7-fa52-6222-e5188d35bed9'}, 'data': {'chunk': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024, featuring the Starlink-197 mission on a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1156, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e1a08ab-b0f8-423b-81a0-a1535b37318e-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 31, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'parent_ids': ['f07acb31-b2ef-4e12-9087-24e54b9df997']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024, featuring the Starlink-197 mission on a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1156, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e1a08ab-b0f8-423b-81a0-a1535b37318e-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 31, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n   ...
# {'event': 'on_chain_stream', 'run_id': 'f07acb31-b2ef-4e12-9087-24e54b9df997', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='The next SpaceX launch is scheduled for October 18, 2024, featuring the Starlink-197 mission on a Falcon 9 rocket.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1156, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e1a08ab-b0f8-423b-81a0-a1535b37318e-0', usage_metadata={'input_tokens': 1156, 'output_tokens': 31, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f48c126a-df7f-48ac-9d73-93d5ec8631a7'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 87, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7dab47ea-8eda-46a4-8506-35a9bb0124c7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_z73NJc4oUnbULbQS5btOSvje', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 22, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'[All Scheduled Launches](https://rocketlaunch.org/launch-schedule)SpaceX\\n\\nNext Launch\\n\\n[Falcon 9 Block 5 | Starlink Group 15-6](https://rocketlaunch.org/mission-falcon-9-block-5-starlink-group-15-6)\\n\\n![Image 1: Mission patch Space X Starlink Mission Patch](https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/mission_patch_images/space2520x252_mission_patch_20221011205756.png)\\n\\nLaunch Countdown\\n\\n17\\n\\nhr\\n\\n27\\n\\nmin\\n\\n01\\n\\nsec\\n\\nDate & Time\\n\\n13 Jun, 1:46am\\n\\nUTC\\n\\nLocation\'}, {\'url\': \'https://www.rocketlaunch.live/?filter=spacex\', \'content\': \'| Selected |\\n| --- |\\n| Providers | all |\\n| Locations | all |\\n| Launches | 26 |\\n\\n### Next SpaceX Launch\\n\\nAPR 03\\n\\n22:54\\n\\n#### [Starlink (11-13)](https://www.rocketlaunch.live/launch/starlink-11-13 "Starlink (11-13) Mission (Falcon 9)")\\n\\n#### [Falcon 9](https://www.rocketlaunch.live/?filter=falcon-9)\\n\\n[SpaceX](https://www.rocketlaunch.live/?filter=spacex) [...] *   OCT 22 2024\\n    \\n    [Tianping-3A(01)](https://www.rocketlaunch.live/launch/tianping-3a-01 "Tianping-3A(01) Mission (Long March 6)")\\n    \\n*   OCT 20 2024\\n    \\n    [OneWeb-20](https://www.rocketlaunch.live/launch/oneweb-20 "OneWeb-20 Mission (Falcon 9)")\\n    \\n*   OCT 18 2024\\n    \\n    [Starlink-197 (8-19)](https://www.rocketlaunch.live/launch/starlink-8-19 "Starlink-197 (8-19) Mission (Falcon 9)")\\n    \\n*   OCT 15 2024 [...] *   NOV 30 2024\\n    \\n    [NROL-126](https://www.rocketlaunch.live/launch/nrol-126 "NROL-126 Mission (Falcon 9)")\\n    \\n*   NOV 30 2024\\n    \\n    [Starlink-212 (6-65)](https://www.rocketlaunch.live/launch/starlink-6-65 "Starlink-212 (6-65) Mission (Falcon 9)")\\n    \\n*   NOV 29 2024\\n    \\n    [Kondor-FKA no.2](https://www.rocketlaunch.live/launch/kondor-fka-no-2 "Kondor-FKA no.2 Mission (Soyuz-2)")\\n    \\n*   NOV 27 2024\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] flight](https://spaceflightnow.com/2025/05/26/live-coverage-spacex-to-launch-its-starship-super-heavy-rocket-on-its-9th-test-flight/ "Launch preview: SpaceX to launch its Starship-Super Heavy rocket on its 9th test flight") [May 26, 2025](https://spaceflightnow.com/2025/05/)\'}, {\'url\': \'https://nextspaceflight.com/\', \'content\': \'SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 12-26\\n\\n ASOG \\n\\nFri Jun 13, 2025 15:21 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \ ...
